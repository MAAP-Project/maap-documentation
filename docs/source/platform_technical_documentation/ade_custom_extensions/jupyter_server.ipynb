# %% [markdown]
# # Jupyter Server Extension
#
# This is the backend extension for the MAAP common collection of custom jupyter extensions. This backend is accessible to users and other jupyter extensions through a RESTful interface. The endpoints supported interact with the MAAP API and user workspace. For a list of the specific endpoints refer to the [repo documentation](https://github.com/MAAP-Project/jupyter-server-extension/blob/main/README.md).
