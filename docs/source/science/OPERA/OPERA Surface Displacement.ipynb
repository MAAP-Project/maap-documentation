# %% [markdown]
# # OPERA Surface Displacement from Sentinel-1 Access and Visualize

# %% [markdown]
# Authors: Harshini Girish (UAH), Rajat Shinde (UAH), Alex Mandel (Development Seed), Chuck Daniels (Development Seed), Julia Signell (Element84)
#
# Date:July 28, 2025
#
# Description: This tutorial aims to provide information and code to help users get started working with the OPERA Sentinel-1 Surface Displacement product using the MAAP. We will search for the data within NASA’s Common Metadata Repository (CMR).

# %% [markdown]
# ## Run This Notebook

# %% [markdown]
# To access and run this tutorial within MAAP’s Algorithm Development Environment (ADE), please refer to the “Getting started with the MAAP” section of our documentation.
#
# Disclaimer: It is highly recommended that you run this tutorial within MAAP’s ADE, which already includes packages specific to MAAP, such as maap-py. Running the tutorial outside of the MAAP ADE may lead to errors.

# %% [markdown]
# ## About the Data

# %% [markdown]
# The Level-3 OPERA Sentinel-1 Surface Displacement (DISP) product is generated through interferometric time-series analysis of Level-2 Coregistered Sentinel-1 Single Look Complex (CSLC) datasets. Using a hybrid Persistent Scatterer (PS) and Distributed Scatterer (DS) approach, this product quantifies Earth's surface displacement in the radar line-of-sight. The DISP products enable the detection of anthropogenic and natural surface changes, including subsidence, tectonic deformation, and landslides.
#
# The OPERA DISP suite comprises complementary datasets derived from Sentinel-1 and NISAR inputs, designated as DISP-S1 and DISP-NI, respectively. Each product, created per acquisition, adheres to a consistent structure, HDF5 file format, file-naming convention, and a 30 m spatial posting. This collection specifically includes DISP-S1 products, derived from Sentinel-1 data. For visualization and quick exploration, the Pangeo Image can be used for these datasets.

# %% [markdown]
# Source: [OPERA Surface Displacement from Sentinel-1](https://cmr.earthdata.nasa.gov/search/concepts/C3294057315-ASF.html)

# %% [markdown]
# ## Importing Packages

# %% [markdown]
# You can access data from Jupyter Notebook within your workspace. In your Jupyter Notebook, start by importing the `maap` package. Then invoke the `MAAP` constructor, setting the `maap_host` argument to `'api.maap-project.org'`

# %%
# --- MAAP & Cloud Access ---
from maap.maap import MAAP
import earthaccess
from s3fs import S3FileSystem

# File Access & Processing -
import os
import fsspec
import h5py
import re
import numpy as np
import xarray as xr
import dask

# Plotting & Visualization 
import matplotlib.pyplot as plt
import folium

#  Geospatial 
import geopandas as gpd
from shapely.geometry import box, Polygon

# Misc
import requests
from pprint import pprint

# Initialize MAAP
maap = MAAP()

# %% [markdown]
# ## Searching the Data

# %% [markdown]
# This performs a granule search using the `maap.searchGranule()` function on the OPERA Sentinel-1 displacement product collection.

# %%
collection = maap.searchCollection(
    cmr_host="cmr.earthdata.nasa.gov",
    short_name="OPERA_L3_DISP-S1_V1"
)
len(collection)
# Out:
# 1

# %%
concept_id = collection[0]["concept-id"]
print(concept_id)
# Out:
# C3294057315-ASF

# %%
results = maap.searchGranule(
    concept_id=concept_id,
    cmr_host="cmr.earthdata.nasa.gov",
    limit=100
)

records = []
for r in results:
    granule = r["Granule"]
    try:
        points = granule["Spatial"]["HorizontalSpatialDomain"]["Geometry"]["GPolygon"]["Boundary"]["Point"]
        coords = [(float(p["PointLongitude"]), float(p["PointLatitude"])) for p in points]
        if len(coords) >= 3:
            polygon = Polygon(coords)
            records.append({
                "GranuleUR": granule["GranuleUR"],
                "geometry": polygon
            })
    except KeyError:
        continue
if records:
    gdf = gpd.GeoDataFrame(records, crs="EPSG:4326")
    print(f"Found {len(gdf)} granules with polygons.")
# Out:
# Found 100 granules with polygons.

# %% [markdown]
# ## Visualizing with Bounding Boxes

# %% [markdown]
# This code creates an interactive map showing bounding boxes for each granule using `folium`. It extracts geometry bounds from a `GeoDataFrame`, constructs a new `GeoDataFrame` of bounding boxes, and overlays them on a Leaflet map with tooltips displaying each granule's ID.

# %%
bounding_boxes = []
granule_ids = []

for i, geom in enumerate(gdf.geometry):
    minx, miny, maxx, maxy = geom.bounds
    bounding_boxes.append(box(minx, miny, maxx, maxy))  
    granule_ids.append(gdf["GranuleUR"][i])


bbox_gdf = gpd.GeoDataFrame({
    "GranuleUR": granule_ids,
    "geometry": bounding_boxes
}, crs="EPSG:4326")


map_center = bbox_gdf.geometry.union_all().centroid
m = folium.Map(location=[map_center.y, map_center.x], zoom_start=6)


for _, row in bbox_gdf.iterrows():
    folium.GeoJson(
        row["geometry"],
        style_function=lambda x: {
            "color": "green",
            "weight": 2,
            "fillOpacity": 0.1
        },
        tooltip=row["GranuleUR"]
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3906f316d17d362b605efcf50fd89d0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3906f316d17d362b605efcf50fd89d0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3906f316d17d362b605efcf50fd89d0 = L.map(
#                 &quot;map_d3906f316d17d362b605efcf50fd89d0&quot;,
#                 {
#                     center: [23.926581576023118, -103.00414443972184],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4da17e9b6cb0091a55352bef033f06c2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4da17e9b6cb0091a55352bef033f06c2.addTo(map_d3906f316d17d362b605efcf50fd89d0);
#
#
#         function geo_json_6755ce6c46497ff2156343f57517faa7_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_6755ce6c46497ff2156343f57517faa7_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_6755ce6c46497ff2156343f57517faa7 = L.geoJson(null, {
#                 onEachFeature: geo_json_6755ce6c46497ff2156343f57517faa7_onEachFeature,
#
#                 style: geo_json_6755ce6c46497ff2156343f57517faa7_styler,
#         });
#
#         function geo_json_6755ce6c46497ff2156343f57517faa7_add (data) {
#             geo_json_6755ce6c46497ff2156343f57517faa7
#                 .addData(data);
#         }
#             geo_json_6755ce6c46497ff2156343f57517faa7_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-100.42898, 16.82786], [-100.42898, 17.97224], [-102.16568, 17.97224], [-102.16568, 16.82786], [-100.42898, 16.82786]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_6755ce6c46497ff2156343f57517faa7.bindTooltip(
#                 `&lt;div&gt;
#                      OPERA_L3_DISP-S1_IW_F40286_VV_20160701T005555Z_20160818T005558Z_v1.0_20250724T212204Z
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             geo_json_6755ce6c46497ff2156343f57517faa7.addTo(map_d3906f316d17d362b605efcf50fd89d0);
#
#
#         function geo_json_31c1f0bba9aa5597a212a094f1eeec37_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_31c1f0bba9aa5597a212a094f1eeec37_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_31c1f0bba9aa5597a212a094f1eeec37 = L.geoJson(null, {
#                 onEachFeature: geo_json_31c1f0bba9aa5597a212a094f1eeec37_onEachFeature,
#
#                 style: geo_json_31c1f0bba9aa5597a212a094f1eeec37_styler,
#         });
#
#         function geo_json_31c1f0bba9aa5597a212a094f1eeec37_add (data) {
#             geo_json_31c1f0bba9aa5597a212a094f1eeec37
#                 .addData(data);
#         }
#             geo_json_31c1f0bba9aa5597a212a094f1eeec37_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-100.42898, 16.82786], [-100.42898, 17.97224], [-102.16568, 17.97224], [-102.16568, 16.82786], [-100.42898, 16.82786]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_31c1f0bba9aa5597a212a094f1eeec37.bindTooltip(
#                 `&lt;div&gt;
#                      OPERA_L3_DISP-S1_IW_F40286_VV_20160701T005555Z_20170322T005556Z_v1.0_20250724T212204Z
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             geo_json_31c1f0bba9aa5597a212a094f1eeec37.addTo(map_d3906f316d17d362b605efcf50fd89d0);
#
#
#         function geo_json_2ae8f8568067c3653eb163db4caccbab_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_2ae8f8568067c3653eb163db4caccbab_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_2ae8f8568067c3653eb163db4caccbab = L.geoJson(null, {
#                 onEachFeature: geo_json_2ae8f8568067c3653eb163db4caccbab_onEachFeature,
#
#                 style: geo_json_2ae8f8568067c3653eb163db4caccbab_styler,
#         });
#
#         function geo_json_2ae8f8568067c

# %% [markdown]
# ## Search Granules using filters

# %% [markdown]
# ### Temporal Filter

# %% [markdown]
# Now that we have our collection ID, let’s search for granules within the collection. We’ll also add a temporal filter to our search. If you would like to search for granules without the temporal filter, simply comment out or remove the `temporal=date_range` line.

# %%
date_range = "2016-07-01T00:00:00Z,2016-07-25T23:59:59Z"

results = maap.searchGranule(
    temporal=date_range,
    concept_id="C3294057315-ASF",
    cmr_host="cmr.earthdata.nasa.gov"
)

print(f"Found {len(results)} granules")
for r in results:
    print(r["Granule"]["GranuleUR"])
# Out:
# Found 20 granules
# OPERA_L3_DISP-S1_IW_F40286_VV_20160701T005555Z_20160818T005558Z_v1.0_20250724T212204Z
# OPERA_L3_DISP-S1_IW_F40286_VV_20160701T005555Z_20170322T005556Z_v1.0_20250724T212204Z
# OPERA_L3_DISP-S1_IW_F40286_VV_20160701T005555Z_20160911T005559Z_v1.0_20250724T212204Z
# OPERA_L3_DISP-S1_IW_F40286_VV_20160701T005555Z_20170226T005556Z_v1.0_20250724T212204Z
# OPERA_L3_DISP-S1_IW_F40286_VV_20160701T005555Z_20171012T005606Z_v1.0_20250724T212204Z
# OPERA_L3_DISP-S1_IW_F40286_VV_20160701T005555Z_20170509T005558Z_v1.0_20250724T212204Z
# OPERA_L3_DISP-S1_IW_F40286_VV_20160701T005555Z_20160725T005557Z_v1.0_20250724T212204Z
# OPERA_L3_DISP-S1_IW_F40286_VV_20160701T005555Z_20170403T005556Z_v1.0_20250724T212204Z
# OPERA_L3_DISP-S1_IW_F40286_VV_20160701T005555Z_20170918T005605Z_v1.0_20250724T212204Z
# OPERA_L3_DISP-S1_IW_F40286_VV_20160701T005555Z_20170602T005559Z_v1.0_20250724T212204Z
# OPERA_L3_DISP-S1_IW_F40286_VV_20160701T005555Z_20171024T005606Z_v1.0_20250724T212204Z
# OPERA_L3_DISP-S1_IW_F40286_VV_20160701T005555Z_20170930T005605Z_v1.0_20250724T212204Z
# OPERA_L3_DISP-S1_IW_F40286_VV_20160701T005555Z_20170310T005556Z_v1.0_20250724T212204Z
# OPERA_L3_DISP-S1_IW_F40286_VV_20160701T005555Z_20170415T005557Z_v1.0_20250724T212204Z
# OPERA_L3_DISP-S1_IW_F40287_VV_20160701T005608Z_20161005T005612Z_v1.0_20250724T213133Z
# OPERA_L3_DISP-S1_IW_F40287_VV_20160701T005608Z_20170202T005609Z_v1.0_20250724T213133Z
# OPERA_L3_DISP-S1_IW_F40287_VV_20160701T005608Z_20161122T005612Z_v1.0_20250724T213133Z
# OPERA_L3_DISP-S1_IW_F40287_VV_20160701T005608Z_20161029T005613Z_v1.0_20250724T213133Z
# OPERA_L3_DISP-S1_IW_F40287_VV_20160701T005608Z_20170214T005609Z_v1.0_20250724T213133Z
# OPERA_L3_DISP-S1_IW_F40287_VV_20160701T005608Z_20170109T005609Z_v1.0_20250724T213133Z

# %% [markdown]
# ### Spatial Filter

# %% [markdown]
# Another filter we can apply is a spatial filter.

# %%
granule_bbox = "-104.57446,23.91956,-101.85669,25.95518" 
collection_id = "C3294057315-ASF"

results = maap.searchGranule(
    concept_id=collection_id,
    bounding_box=granule_bbox,
    cmr_host="cmr.earthdata.nasa.gov"
)

print(f"Found {len(results)} granules")
for r in results:
    print(r["Granule"]["GranuleUR"])
# Out:
# Found 20 granules
# OPERA_L3_DISP-S1_IW_F40291_VV_20160701T005736Z_20161029T005740Z_v1.0_20250724T213304Z
# OPERA_L3_DISP-S1_IW_F40291_VV_20160701T005736Z_20170310T005736Z_v1.0_20250724T213304Z
# OPERA_L3_DISP-S1_IW_F40291_VV_20160701T005736Z_20161005T005740Z_v1.0_20250724T213304Z
# OPERA_L3_DISP-S1_IW_F40291_VV_20160701T005736Z_20160725T005737Z_v1.0_20250724T213304Z
# OPERA_L3_DISP-S1_IW_F40291_VV_20160701T005736Z_20170403T005737Z_v1.0_20250724T213304Z
# OPERA_L3_DISP-S1_IW_F40291_VV_20160701T005736Z_20161216T005739Z_v1.0_20250724T213304Z
# OPERA_L3_DISP-S1_IW_F40291_VV_20160701T005736Z_20170214T005736Z_v1.0_20250724T213304Z
# OPERA_L3_DISP-S1_IW_F40291_VV_20160701T005736Z_20170322T005736Z_v1.0_20250724T213304Z
# OPERA_L3_DISP-S1_IW_F40291_VV_20160701T005736Z_20161122T005739Z_v1.0_20250724T213304Z
# OPERA_L3_DISP-S1_IW_F40291_VV_20160701T005736Z_20170226T005736Z_v1.0_20250724T213304Z
# OPERA_L3_DISP-S1_IW_F40291_VV_20160701T005736Z_20160818T005738Z_v1.0_20250724T213304Z
# OPERA_L3_DISP-S1_IW_F40291_VV_20160701T005736Z_20170109T005737Z_v1.0_20250724T213304Z
# OPERA_L3_DISP-S1_IW_F40291_VV_20160701T005736Z_20160911T005739Z_v1.0_20250724T213304Z
# OPERA_L3_DISP-S1_IW_F40291_VV_20160701T005736Z_20170202T005736Z_v1.0_20250724T213304Z
# OPERA_L3_DISP-S1_IW_F40292_VV_20160701T005758Z_20160725T005759Z_v1.0_20250412T124848Z
# OPERA_L3_DISP-S1_IW_F40292_VV_20160701T005758Z_20170109T005759Z_v1.0_20250412T124848Z
# OPERA_L3_DISP-S1_IW_F40292_VV_20160701T005758Z_20160818T005800Z_v1.0_20250412T124848Z
# OPERA_L3_DISP-S1_IW_F40292_VV_20160701T005758Z_20161029T005802Z_v1.0_20250412T124848Z
# OPERA_L3_DISP-S1_IW_F40292_VV_20160701T005758Z_20170310T005758Z_v1.0_20250412T124848Z
# OPERA_L3_DISP-S1_IW_F40292_VV_20160701T005758Z_20170403T005759Z_v1.0_20250412T124848Z

# %% [markdown]
# ## Locally download and Inspect

# %% [markdown]
# This code snippet queries NASA’s CMR via the MAAP API to fetch a granule from the `OPERA_L3_DISP-S1_V1` collection and downloads it locally into a folder called `opera_data`. It then uses `xarray.open_dataset()` with the `h5netcdf` engine to open the local NetCDF file and inspects its structure, including its shape, coordinates, and variable metadata.

# %%
results = maap.searchGranule(
    short_name="OPERA_L3_DISP-S1_V1",
    cmr_host="cmr.earthdata.nasa.gov"
)


data_dir = "opera_data"
os.makedirs(data_dir, exist_ok=True)


file_path = results[0].getData(data_dir)

ds = xr.open_dataset(file_path, engine="h5netcdf")
print(ds)
# Out:
# <xarray.Dataset> Size: 4GB
# Dimensions:                         (time: 1, y: 7915, x: 9548)
# Coordinates:
#   * y                               (y) float64 63kB 1.995e+06 ... 1.758e+06
#   * x                               (x) float64 76kB 7.682e+04 ... 3.632e+05
#   * time                            (time) datetime64[ns] 8B 2016-08-18T00:55...
# Data variables: (12/13)
#     spatial_ref                     int64 8B ...
#     reference_time                  (time) datetime64[ns] 8B ...
#     displacement                    (y, x) float64 605MB ...
#     short_wavelength_displacement   (y, x) float32 302MB ...
#     recommended_mask                (y, x) float32 302MB ...
#     connected_component_labels      (y, x) float32 302MB ...
#     ...                              ...
#     estimated_phase_quality         (y, x) float32 302MB ...
#     persistent_scatterer_mask       (y, x) float32 302MB ...
#     shp_counts                      (y, x) float32 302MB ...
#     water_mask                      (y, x) float32 302MB ...
#     phase_similarity                (y, x) float32 302MB ...
#     timeseries_inversion_residuals  (y, x) float32 302MB ...
# Attributes:
#     Conventions:         CF-1.8
#     contact:             opera-sds-ops@jpl.nasa.gov
#     institution:         NASA JPL
#     mission_name:        OPERA
#     reference_document:  JPL D-108765
#     title:               OPERA_L3_DISP-S1 Product

# %% [markdown]
# ## Visualization

# %% [markdown]
# This plot visualizes the radar Line-of-Sight (LOS) displacement from an OPERA DISP-S1 granule. The displacement field is displayed with a diverging colormap, highlighting motion towards and away from the sensor.

# %%
ds["displacement"].attrs
# Out:
# {'units': 'meters',
#  'description': 'Displacement along the radar Line-of-Sight (LOS) direction. Positive values indicate apparent motion towards the platform.',
#  'long_name': 'Line-of-sight displacement',
#  'grid_mapping': 'spatial_ref'}

# %%
gname = results[0]["Granule"]["GranuleUR"]
t = re.search(r'_(\d{8}T\d{6}Z)_(\d{8}T\d{6}Z)', gname)
ts = f"{t.group(1)} to {t.group(2)}" if t else "Time unknown"

ds["displacement"].squeeze().plot(
    cmap="RdBu", vmin=-0.1, vmax=0.1, figsize=(8, 6),
    cbar_kwargs={"label": "Line-of-sight displacement [m]"}
)
plt.title(f"LOS displacement from {ts}")
plt.xlabel("X coord [m]"); plt.ylabel("Y coord [m]")
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Remote Access

# %% [markdown]
# This example streams a NetCDF file directly from AWS S3 using `fsspec` and valid Earthdata S3 credentials. The `getDownloadUrl()` method fetches the granule's S3 path, which is securely accessed using temporary keys. The dataset is then opened with `xarray` using the `h5netcdf` engine, without needing to download the file locally.

# %%
results = maap.searchGranule(
    concept_id="C3294057315-ASF",
    cmr_host="cmr.earthdata.nasa.gov",
    limit=10,
)


print(results[0].getDownloadUrl())


credentials = maap.aws.earthdata_s3_credentials(
    'https://cumulus.asf.alaska.edu/s3credentials'
)


s3 = fsspec.filesystem(
    "s3",
    key=credentials['accessKeyId'],
    secret=credentials['secretAccessKey'],
    token=credentials['sessionToken']
)
# Out:
# s3://asf-cumulus-prod-opera-products/OPERA_L3_DISP-S1_V1/OPERA_L3_DISP-S1_IW_F40286_VV_20160701T005555Z_20160818T005558Z_v1.0_20250724T212204Z/OPERA_L3_DISP-S1_IW_F40286_VV_20160701T005555Z_20160818T005558Z_v1.0_20250724T212204Z.nc

# %%
with s3.open(results[0].getDownloadUrl(), "rb") as f:
    ds = xr.open_dataset(f, engine="h5netcdf")
    print(ds)
# Out:
# <xarray.Dataset> Size: 4GB
# Dimensions:                         (time: 1, y: 7915, x: 9548)
# Coordinates:
#   * y                               (y) float64 63kB 1.995e+06 ... 1.758e+06
#   * x                               (x) float64 76kB 7.682e+04 ... 3.632e+05
#   * time                            (time) datetime64[ns] 8B 2016-08-18T00:55...
# Data variables: (12/13)
#     spatial_ref                     int64 8B ...
#     reference_time                  (time) datetime64[ns] 8B ...
#     displacement                    (y, x) float64 605MB ...
#     short_wavelength_displacement   (y, x) float32 302MB ...
#     recommended_mask                (y, x) float32 302MB ...
#     connected_component_labels      (y, x) float32 302MB ...
#     ...                              ...
#     estimated_phase_quality         (y, x) float32 302MB ...
#     persistent_scatterer_mask       (y, x) float32 302MB ...
#     shp_counts                      (y, x) float32 302MB ...
#     water_mask                      (y, x) float32 302MB ...
#     phase_similarity                (y, x) float32 302MB ...
#     timeseries_inversion_residuals  (y, x) float32 302MB ...
# Attributes:
#     Conventions:         CF-1.8
#     contact:             opera-sds-ops@jpl.nasa.gov
#     institution:         NASA JPL
#     mission_name:        OPERA
#     reference_document:  JPL D-108765
#     title:               OPERA_L3_DISP-S1 Product

# %% [markdown]
# ## Visualization

# %% [markdown]
# The plot shows pixel-level surface displacement values without downloading the file locally.

# %%
url = results[0].getDownloadUrl()
match = re.search(r'_(\d{8}T\d{6})Z_(\d{8}T\d{6})Z', url)
start_date, end_date = match.groups() if match else ("Unknown", "Unknown")
with (
    s3.open(results[0].getDownloadUrl(), "rb") as f,
    h5py.File(f, "r") as opera_data,
):
    displacement_data = opera_data["displacement"][:]
    displacement_data = np.ma.masked_where(np.isnan(displacement_data), displacement_data)

   
    plt.figure(figsize=(8, 6))
    im = plt.imshow(displacement_data, cmap="RdBu", vmin=-0.1, vmax=0.1)
    cbar = plt.colorbar(im)
    cbar.set_label("Line-of-sight displacement [m]")

    plt.title(
        f"Surface Displacement (OPERA DISP–S1)\nLOS difference from {start_date} to {end_date}"
    )
    plt.xlabel("X coordinate of projection [m]")
    plt.ylabel("Y coordinate of projection [m]")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Testing Cloud Optimization

# %% [markdown]
# This setup enables efficient streaming of large NetCDF files from NASA’s cloud using `earthaccess` and `fsspec`. By specifying `blockcache` and tuning HDF5 driver settings like `page_buf_size` and `rdcc_nbytes`, it optimizes chunked reads. The dataset is opened in-memory with `xr.open_dataset()` using `h5netcdf`, without downloading locally.

# %%
auth = earthaccess.login()

granules = earthaccess.search_data(
    count=1,
    short_name="OPERA_L3_DISP-S1_V1"
)
granule = granules[0]
url = granule.data_links(access="direct")[0]

credentials = auth.get_s3_credentials(
    endpoint=granule.get_s3_credentials_endpoint()
)

s3 = S3FileSystem(
    key=credentials['accessKeyId'],
    secret=credentials['secretAccessKey'],
    token=credentials['sessionToken']
)

# %%
io_params = {
    "fsspec_params": {
        "cache_type": "blockcache",
        "block_size": 8 * 1024 * 1024
    },
    "h5py_params": {
        "driver_kwds": {
            "page_buf_size": 16 * 1024 * 1024,
            "rdcc_nbytes": 4 * 1024 * 1024
        }
    }
}

# %%
ds = xr.open_dataset(
    s3.open(url, "rb", **io_params["fsspec_params"]),
    engine="h5netcdf",
    chunks="auto",  
    **io_params["h5py_params"]
)

# %% [markdown]
# Each data variable (e.g., `displacement`, `temporal_coherence`like (5632, 2283), (5632, 3916), or (4096, 3819). This chunking enables partial reads using HTTP range requests via `fsspec` without loading the full file. It's ideal for efficient, on-demand access in cloud environments.

# %%
for var_name, variable in ds.data_vars.items():
    print(f"Variable '{var_name}': chunks = {variable.chunks}")
# Out:
# Variable 'spatial_ref': chunks = None
# Variable 'reference_time': chunks = ((1,),)
# Variable 'displacement': chunks = ((4096, 3819), (4096, 4096, 1356))
# Variable 'short_wavelength_displacement': chunks = ((5632, 2283), (5632, 3916))
# Variable 'recommended_mask': chunks = ((5632, 2283), (5632, 3916))
# Variable 'connected_component_labels': chunks = ((5632, 2283), (5632, 3916))
# Variable 'temporal_coherence': chunks = ((5632, 2283), (5632, 3916))
# Variable 'estimated_phase_quality': chunks = ((5632, 2283), (5632, 3916))
# Variable 'persistent_scatterer_mask': chunks = ((5632, 2283), (5632, 3916))
# Variable 'shp_counts': chunks = ((5632, 2283), (5632, 3916))
# Variable 'water_mask': chunks = ((5632, 2283), (5632, 3916))
# Variable 'phase_similarity': chunks = ((5632, 2283), (5632, 3916))
# Variable 'timeseries_inversion_residuals': chunks = ((5632, 2283), (5632, 3916))

# %% [markdown]
# ## Cloud-Optimized Performance

# %% [markdown]
# This code uses `isel()` to select a small index-based window from the `displacement` variable. It applies `.compute()` to load only the required chunks with Dask. After filtering out NaNs, it plots a histogram of valid displacement values.

# %%
# %time subset = ds['displacement'].isel(y=slice(230, 250), x=slice(8390, 8410)).compute()
# Out:
# CPU times: user 8.95 ms, sys: 479 µs, total: 9.43 ms
# Wall time: 10.5 ms

# %%
subset_vals = subset.values.flatten()
subset_vals = subset_vals[~np.isnan(subset_vals)]

plt.hist(subset_vals, bins=50)
plt.title("Histogram of Displacement (Index-Based Subset)")
plt.xlabel("Displacement (m)")
plt.ylabel("Frequency")
plt.show()
