# %% [markdown]
# ## Getting started with the MAAP

# %% [markdown]
# Learn how to sign up for an account and access all the services of the MAAP.

# %% [markdown]
# ### Signing up for an Earthdata Login account

# %% [markdown]
# The MAAP offers accounts for NASA users through [Earthdata Login](https://urs.earthdata.nasa.gov/). Before accessing the MAAP as a NASA user, you will need to an Earthdata Login account. Anyone can register for an Earthdata Login profile here: https://urs.earthdata.nasa.gov/users/new.

# %% [markdown]
# ### Signing up for a new MAAP account

# %% [markdown]
# Once registered, you can register for a MAAP account by navigating to the MAAP ADE: http://ade.maap-project.org. On your first visit, select the "URS" login button shown here:
#
# ![pyCMC mapview](_static/ade_login.png)
#
# If this is your first visit to the MAAP, you will asked to agree to the MAAP Terms of Use:
#
# ![pyCMC mapview](_static/tou.png)
#
# Once registered, you should be redirected back to the MAAP ADE showing a disabled account message similar to this:
#
# ![pyCMC mapview](_static/access_denied.png)
#
# At this point, a MAAP administrator will approve your account which will grant you access to the MAAP ADE. This process typically takes 5-10 minutes. To check on the status of your pending account, contact the MAAP team at support@maap-project.org. (TODO: decide on what contact email to use!)
#
# Once your MAAP account is approved, you will receive an email notification at the email address associated with your Earthdata Login account letting you know that your access is enabled.

# %% [markdown]
# ### Code repository access

# %% [markdown]
# After creating your MAAP account, you can create a code repository by navigating to the MAAP GitLab account at https://repo.maap-project.org. This GitLab account is connected to your ADE workspaces automatically when signing into the ADE.

# %% [markdown]
# ### Uploading your public SSH key

# %% [markdown]
# In order to access your ADE workspaces using SSH, you'll need to upload your public SSH key to your MAAP profile using the MAAP portal at https://www.maap-project.org.
#
# Click on your profile name (or the "Login" button) in the top right corner shown here:
#
# ![pyCMC mapview](_static/portal.png)
#
# On your profile page, click the "Choose File" button to upload your key,
#
# ![pyCMC mapview](_static/sshkey.png)
#
# After uploading your key, the SSH connection will be enabled **after your next** login into the ADE.
